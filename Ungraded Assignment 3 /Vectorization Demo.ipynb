# %%
import numpy as np

# %%
a=np.array([1,1,2,3])
print(a)
# Out:
# [1 1 2 3]

# %%
import time

# %%
t1=time.time()

a=np.random.rand(100000)
b=np.random.rand(100000)

c=np.dot(a,b)

t2=time.time()

print("Time taken: "+str(1000*(t2-t1))+" msecs")

c=0

t1=time.time()

for i in range(100000):
  c=c+a[i]*b[i]

t2=time.time()

print("Time taken: "+str(1000*(t2-t1))+" msecs")
# Out:
# Time taken: 6.360530853271484 msecs
# Time taken: 116.91999435424805 msecs
