# %%
1+1
# Out:
# 2

# %% [markdown]
# My first markdown cell1

# %%
3/2
# Out:
# 1.5

# %%
1+1
# Out:
# 2

# %% [markdown]
# _italic_

# %% [markdown]
# __bold__

# %% [markdown]
# `inline`

# %% [markdown]
# >blockquote

# %% [markdown]
# [google](http://google.com/)

# %% [markdown]
# #Heading

# %% [markdown]
# ##Heading2

# %% [markdown]
# ####Heading4

# %% [markdown]
# Ordered list1
# 1. List1
#     2. List2

# %% [markdown]
# Unordered list
# * Apple
# * Mango
# * Banana

# %% [markdown]
# Task list
# - [x] Data Mining
#     - [x] Homework1

# %%
  # !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# mkdir: /root/.torch/models: Read-only file system
# mkdir: /root/.fastai/data: Read-only file system
# ln: /content: Read-only file system
# ln: /content: Read-only file system
# Updating fastai...
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# ERROR: sklearn-pandas 1.8.0 has requirement scipy>=0.14, but you'll have scipy 0.13.0b1 which is incompatible.
# ERROR: opencv-python 4.1.2.30 has requirement numpy>=1.11.1, but you'll have numpy 1.8.0rc1 which is incompatible.
# ERROR: torchvision 0.5.0 has requirement torch==1.4.0, but you'll have torch 0.3.1 which is incompatible.
# ERROR: pyarrow 0.15.1 has requirement numpy>=1.14, but you'll have numpy 1.8.0rc1 which is incompatible.
# ERROR: seaborn 0.9.1 has requirement matplotlib>=1.5.3, but you'll have matplotlib 1.3.1 which is incompatible.
# ERROR: seaborn 0.9.1 has requirement numpy>=1.10.4, but you'll have numpy 1.8.0rc1 which is incompatible.
# ERROR: seaborn 0.9.1 has requirement scipy>=0.17.1, but you'll have scipy 0.13.0b1 which is incompatible.
# ERROR: scikit-learn 0.20.4 has requirement numpy>=1.8.2, but you'll have numpy 1.8.0rc1 which is incompatible.
# ERROR: scikit-learn 0.20.4 has requirement scipy>=0.13.3, but you'll have scipy 0.13.0b1 which is incompatible.
# ERROR: pandas 0.24.2 has requirement numpy>=1.12.0, but you'll have numpy 1.8.0rc1 which is incompatible.
# ERROR: pandas 0.24.2 has requirement python-dateutil>=2.5.0, but you'll have python-dateutil 1.5 which is incompatible.
# ERROR: statsmodels 0.11.0 has requirement numpy>=1.14, but you'll have numpy 1.8.0rc1 which is incompatible.
# ERROR: statsmodels 0.11.0 has requirement scipy>=1.0, but you'll have scipy 0.13.0b1 which is incompatible.
# ERROR: jupyter-client 5.3.4 has requirement python-dateutil>=2.1, but you'll have python-dateutil 1.5 which is incompatible.
# ERROR: plotnine 0.4.0 has requirement matplotlib>=2.1.0, but you'll have matplotlib 1.3.1 which is incompatible.
# ERROR: plotnine 0.4.0 has requirement scipy>=1.0.0, but you'll have scipy 0.13.0b1 which is incompatible.
# ERROR: Could not install packages due to an EnvironmentError: [Errno 13] Permission denied: '/Library/Python/2.7/site-packages/bcolz'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 19.2.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Done.

# %%
# Import necessary libraries
from fastai.vision import * 
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
a = 1
b = a + 1
c = b + a + 1
d = c + b + a + 1
a, b, c ,d
# Out:
# (1, 2, 4, 8)

# %%
plt.plot([a,b,c,d])
plt.show()

# %%
Image.open('/Users/rimzimthube/Downloads/TitanicWordCloud.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x768 at 0x1A26D15790>
