# %% [markdown]
# Keras Fashion MNIST classifier

# %%
import numpy as np
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten

# %% [markdown]
# Load the data and do data analysis

# %%
# Load the dataset
(xtrain,ytrain),(xtest,ytest)=fashion_mnist.load_data()

# %%
type(xtrain[0])
# Out:
# numpy.ndarray

# %%
xtrain.shape
# Out:
# (60000, 28, 28)

# %%
ytrain.shape
# Out:
# (60000,)

# %%
xtest.shape
# Out:
# (10000, 28, 28)

# %%
ytest.shape
# Out:
# (10000,)

# %%
ytrain
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# Convert x values in the range from 0 to 1

# %%
# Convert the values in 0 to 1
xtrain=xtrain/255

# %%
xtest=xtest/255

# %% [markdown]
# Create the architecture of the model

# %%
model=Sequential()

# %%
model.add(Flatten(input_shape=(28,28)))

# %%
model.add(Dense(128,activation='relu'))

# %%
model.add(Dense(10,activation='softmax',))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_3 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1290
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compile the model

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3622: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# Fit the model to the training data

# %%
model.fit(xtrain, ytrain, epochs=20)
# Out:
# Epoch 1/20
# 60000/60000 [==============================] - 6s 102us/step - loss: 0.2307 - acc: 0.9141
# Epoch 2/20
# 60000/60000 [==============================] - 6s 102us/step - loss: 0.2249 - acc: 0.9154
# Epoch 3/20
# 60000/60000 [==============================] - 7s 110us/step - loss: 0.2179 - acc: 0.9193
# Epoch 4/20
# 60000/60000 [==============================] - 6s 108us/step - loss: 0.2099 - acc: 0.9208
# Epoch 5/20
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.2051 - acc: 0.9222
# Epoch 6/20
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.2001 - acc: 0.9245
# Epoch 7/20
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.1941 - acc: 0.9259
# Epoch 8/20
# 60000/60000 [==============================] - 6s 103us/step - loss: 0.1879 - acc: 0.9293
# Epoch 9/20
# 60000/60000 [==============================] - 6s 101us/step - loss: 0.1832 - acc: 0.9304
# Epoch 10/20
# ...

# %% [markdown]
# Evaluate the model

# %%
loss, accuracy=model.evaluate(xtest,ytest)
# Out:
# 10000/10000 [==============================] - 0s 31us/step

# %% [markdown]
# The accuracy of the model

# %%
accuracy
# Out:
# 0.8833

# %%
from keras.preprocessing import image

# %%
temp=image.load_img('IMG_8321.jpg',grayscale=True,target_size=(28,28))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
# Out:
# <bound method Image.show of <PIL.Image.Image image mode=L size=28x28 at 0x7F2662B3AE10>>
